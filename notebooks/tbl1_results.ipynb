# %% [markdown]
# # Table 1. Neuron-based classification results in 4-way evaluation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir('..')

# %%
neuron_df = pd.read_csv('experiments/trials/results/neuron_classification.csv')
neuron_4way_df = neuron_df[neuron_df['num_img_per_trial'] == 4]
neuron_4way_df
# Out:
#      overall_accuracy                model  batch_size  device  seed  \
# 3            0.778333         cvcl-resnext         200  cuda:0     0
# 4            0.782500         cvcl-resnext         200  cuda:0     1
# 5            0.758750         cvcl-resnext         200  cuda:0     2
# 18           0.279167  cvcl-resnext-random         200  cuda:0     0
# 19           0.286667  cvcl-resnext-random         200  cuda:0     1
# 20           0.314583  cvcl-resnext-random         200  cuda:0     2
# 33           0.909091             clip-res         200  cuda:0     0
# 34           0.913030             clip-res         200  cuda:0     1
# 35           0.908485             clip-res         200  cuda:0     2
# 48           0.883411              resnext         200  cuda:0     0
# 49           0.882481              resnext         200  cuda:0     1
# 50           0.885271              resnext         200  cuda:0     2
# 63           0.785926     dino_s_resnext50         200  cuda:0     0
# 64           0.787037     dino_s_resnext50         200  cuda:0     1
# 65           0.775185     dino_s_resnext50         200  cuda:0     2
# 78           0.776282         cvcl-resnext         200  cuda:0     0
# 79           0.778846         cvcl-resnext         200  cuda:0     1
# 80           0.769444         cvcl-resnext         200  cuda:0     2
# 93           0.894249             clip-res         200  cuda:0     0
# 94           0.888777             clip-res         200  cuda:0     1
# 95           0.883975             clip-res         200  cuda:0     2
# 108          0.912912              resnext         200  cuda:0     0
# 109          0.913344              resnext         200  cuda:0     1
# 110          0.916586              resnext         200  cuda:0     2
# 123          0.779204     dino_s_resnext50         200  cuda:0     0
# 124          0.780088     dino_s_resnext50         200  cuda:0     1
# 125          0.773746     dino_s_resnext50         200  cuda:0     2
#
#     trial_type class_type  object_resize  num_img_per_trial  \
# 3       custom       seen          False                  4
# 4       custom       seen          False                  4
# 5       custom       seen          False                  4
# 18      custom       seen          False                  4
# 19      custom       seen          False                  4
# 20      custom       seen          False                  4
# 33      custom       seen          False                  4
# 34      custom       seen          False                  4
# 35      custom       seen          False                  4
# 48      custom       seen          False                  4
# 49      custom       seen          False                  4
# 50      custom       seen          False                  4
# 63      custom       seen          False                  4
# 64      custom       seen          False                  4
# 65      custom       seen          False                  4
# 78      custom     unseen          False                  4
# 79      custom     unseen          False                  4
# 80      custom     unseen          False                  4
# 93      custom       full          False                  4
# 94      custom       full          False                  4
# 95      custom       full          False                  4
# 108     custom       full          False                  4
# 109     custom       full          False                  4
# 110     custom       full          False                  4
# 123     custom       full          False                  4
# 124     custom       full          False                  4
# 125     custom       full          False                  4
#
#      num_trials_per_image  layers  top_k  \
# 3                       5     NaN      1
# 4                       5     NaN      1
# 5                       5     NaN      1
# 18                      5     NaN      1
# 19                      5     NaN      1
# 20                      5     NaN      1
# 33                      5     NaN      1
# 34                      5     NaN      1
# 35                      5     NaN      1
# 48                      5     NaN      1
# 49                      5     NaN      1
# 50                      5     NaN      1
# 63                      5     NaN      1
# 64                      5     NaN      1
# 65                      5     NaN      1
# 78                      5     NaN      1
# 79                      5     NaN      1
# 80                      5     NaN      1
# 93                      5     NaN      1
# 94                      5     NaN      1
# 95                      5     NaN      1
# 108                     5     NaN      1
# 109                     5     NaN      1
# 110                     5     NaN      1
# 123                     5     NaN      1
# 124                     5     NaN      1
# 125                     5     NaN      1
#
#                                               map_file  \
# 3    ./experiments/neuron_labeling/labeled_neurons/...
# 4    ./experiments/neuron_labeling/labeled_neurons/...
# 5    ./experiments/neuron_labeling/labeled_neurons/...
# 18   ./experiments/neuron_labeling/labeled_neurons/...
# 19   ./experiments/neuron_labeling/labeled_neurons/...
# 20   ./experiments/neuron_labeling/labeled_neurons/...
# 33   ./experiments/neuron_labeling/labeled_neurons/...
# 34   ./experiments/neuron_labeling/labeled_neurons/...
# 35   ./experiments/neuron_labeling/labeled_neurons/...
# 48   ./experiments/neuron_labeling/labeled_neurons/...
# 49   ./experiments/neuron_labeling/labeled_neurons/...
# 50   ./experiments/neuron_labeling/labeled_neurons/...
# 63   ./experiments/neuron_labeling/labeled_neurons/...
# 64   ./experiments/neuron_labeling/labeled_neurons/...
# 65   ./experiments/neuron_labeling/labeled_neurons/...
# 78   ./experiments/neuron_labeling/labeled_neurons/...
# 79   ./experiments/neuron_labeling/labeled_neurons/...
# 80   ./experiments/neuron_labeling/labeled_neurons/...
# 93   ./experiments/neuron_labeling/labeled_neurons/...
# 94   ./experiments/neuron_labeling/labeled_neurons/...
# 95   ./experiments/neuron_labeling/labeled_neurons/...
# 108  ./experiments/neuron_labeling/labeled_neurons/...
# 109  ./experiments/neuron_labeling/labeled_neurons/...
# 110  ./experiments/neuron_labeling/labeled_neurons/...
# 123  ./experiments/neuron_labeling/labeled_neurons/...
# 124  ./experiments/neuron_labeling/labeled_neurons/...
# 125  ./experiments/neuron_labeling/labeled_neurons/...
#
#                                          csv_save_path  \
# 3    ./experiments/trials/results/neuron_classifica...
# 4    ./experiments/trials/results/neuron_classifica...
# 5    ./experiments/trials/results/neuron_classifica...
# 18   ./experiments/trials/results/neuron_classifica...
# 19   ./experiments/trials/results/neuron_classifica...
# 20   ./experiments/trials/results/neuron_classifica...
# 33   ./experiments/trials/results/neuron_classifica...
# 34   ./experiments/trials/results/neuron_classifica...
# 35   ./experiments/trials/results/neuron_classifica...
# 48   ./experiments/trials/results/neuron_classifica...
# 49   ./experiments/trials/results/neuron_classifica...
# 50   ./experiments/trials/results/neuron_classifica...
# 63   ./experiments/trials/results/neuron_classifica...
# 64   ./experiments/trials/results/neuron_classifica...
# 65   ./experiments/trials/results/neuron_classifica...
# 78   ./experiments/trials/results/neuron_classifica...
# 79   ./experiments/trials/results/neuron_classifica...
# 80   ./experiments/trials/results/neuron_classifica...
# 93   ./experiments/trials/results/neuron_classifica...
# 94   ./experiments/trials/results/neuron_classifica...
# 95   ./experiments/trials/results/neuron_classifica...
# 108  ./experiments/trials/results/neuron_classifica...
# 109  ./experiments/trials/results/neuron_classifica...
# 110  ./experiments/trials/results/neuron_classifica...
# 123  ./experiments/trials/results/neuron_classifica...
# 124  ./experiments/trials/results/neuron_classifica...
# 125  ./experiments/trials/results/neuron_classifica...
#
#                      exps_root_dir  \
# 3    ./experiments/trials/neurons/
# 4    ./experiments/trials/neurons/
# 5    ./experiments/trials/neurons/
# 18   ./experiments/trials/neurons/
# 19   ./experiments/trials/neurons/
# 20   ./experiments/trials/neurons/
# 33   ./experiments/trials/neurons/
# 34   ./experiments/trials/neurons/
# 35   ./experiments/trials/neurons/
# 48   ./experiments/trials/neurons/
# 49   ./experiments/trials/neurons/
# 50   ./experiments/trials/neurons/
# 63   ./experiments/trials/neurons/
# 64   ./experiments/trials/neurons/
# 65   ./experiments/trials/neurons/
# 78   ./experiments/trials/neurons/
# 79   ./experiments/trials/neurons/
# 80   ./experiments/trials/neurons/
# 93   ./experiments/trials/neurons/
# 94   ./experiments/trials/neurons/
# 95   ./experiments/trials/neurons/
# 108  ./experiments/trials/neurons/
# 109  ./experiments/trials/neurons/
# 110  ./experiments/trials/neurons/
# 123  ./experiments/trials/neurons/
# 124  ./experiments/trials/neurons/
# 125  ./experiments/trials/neurons/
#
#                                             trial_path  \
# 3    data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 4    data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 5    data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 18   data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 19   data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 20   data/trials/seen_cvcl_objects_baby+30k+konk_ob...
# 33   data/trials/seen_clip_objects_baby+30k+konk_ob...
# 34   data/trials/seen_clip_objects_baby+30k+konk_ob...
# 35   data/trials/seen_clip_objects_baby+30k+konk_ob...
# 48   data/trials/seen_resnext_objects_baby+30k+konk...
# 49   data/trials/seen_resnext_objects_baby+30k+konk...
# 50   data/trials/seen_resnext_objects_baby+30k+konk...
# 63   data/trials/seen_dino_objects_baby+30k+konk_ob...
# 64   data/trials/seen_dino_objects_baby+30k+konk_ob...
# 65   data/trials/seen_dino_objects_baby+30k+konk_ob...
# 78   data/trials/unseen_cvcl_objects_baby+30k+konk_...
# 79   data/trials/unseen_cvcl_objects_baby+30k+konk_...
# 80   data/trials/unseen_cvcl_objects_baby+30k+konk_...
# 93   data/trials/full_clip_objects_baby+30k+konk_ob...
# 94   data/trials/full_clip_objects_baby+30k+konk_ob...
# 95   data/trials/full_clip_objects_baby+30k+konk_ob...
# 108  data/trials/full_resnext_objects_baby+30k+konk...
# 109  data/trials/full_resnext_objects_baby+30k+konk...
# 110  data/trials/full_resnext_objects_baby+30k+konk...
# 123  data/trials/full_dino_objects_baby+30k+konk_ob...
# 124  data/trials/full_dino_objects_baby+30k+konk_ob...
# 125  data/trials/full_dino_objects_baby+30k+konk_ob...
#
#                                            results_dir
# 3    ./experiments/trials/neurons/cvcl-resnext_cust...
# 4    ./experiments/trials/neurons/cvcl-resnext_cust...
# 5    ./experiments/trials/neurons/cvcl-resnext_cust...
# 18   ./experiments/trials/neurons/cvcl-resnext-rand...
# 19   ./experiments/trials/neurons/cvcl-resnext-rand...
# 20   ./experiments/trials/neurons/cvcl-resnext-rand...
# 33   ./experiments/trials/neurons/clip-res_custom_2...
# 34   ./experiments/trials/neurons/clip-res_custom_2...
# 35   ./experiments/trials/neurons/clip-res_custom_2...
# 48   ./experiments/trials/neurons/resnext_custom_20...
# 49   ./experiments/trials/neurons/resnext_custom_20...
# 50   ./experiments/trials/neurons/resnext_custom_20...
# 63   ./experiments/trials/neurons/dino_s_resnext50_...
# 64   ./experiments/trials/neurons/dino_s_resnext50_...
# 65   ./experiments/trials/neurons/dino_s_resnext50_...
# 78   ./experiments/trials/neurons/cvcl-resnext_cust...
# 79   ./experiments/trials/neurons/cvcl-resnext_cust...
# 80   ./experiments/trials/neurons/cvcl-resnext_cust...
# 93   ./experiments/trials/neurons/clip-res_custom_2...
# 94   ./experiments/trials/neurons/clip-res_custom_2...
# 95   ./experiments/trials/neurons/clip-res_custom_2...
# 108  ./experiments/trials/neurons/resnext_custom_20...
# 109  ./experiments/trials/neurons/resnext_custom_20...
# 110  ./experiments/trials/neurons/resnext_custom_20...
# 123  ./experiments/trials/neurons/dino_s_resnext50_...
# 124  ./experiments/trials/neurons/dino_s_resnext50_...
# 125  ./experiments/trials/neurons/dino_s_resnext50_...

# %%
vanilla_df = pd.read_csv('experiments/trials/results/baseline.csv')
vanilla_4way_df = vanilla_df[vanilla_df['num_img_per_trial'] == 4]
vanilla_4way_df
# Out:
#     overall_accuracy         model  batch_size  device  seed trial_type  \
# 3           0.369792  cvcl-resnext         256  cuda:0     0     custom
# 4           0.359167  cvcl-resnext         256  cuda:0     1     custom
# 5           0.368958  cvcl-resnext         256  cuda:0     2     custom
# 18          0.987500      clip-res         256  cuda:0     0     custom
# 19          0.986875      clip-res         256  cuda:0     1     custom
# 20          0.987708      clip-res         256  cuda:0     2     custom
# 33          0.969306      clip-res         256  cuda:0     0     custom
# 34          0.970186      clip-res         256  cuda:0     1     custom
# 35          0.968622      clip-res         256  cuda:0     2     custom
# 48          0.974451      clip-res         256  cuda:0     0     custom
# 49          0.975250      clip-res         256  cuda:0     1     custom
# 50          0.973586      clip-res         256  cuda:0     2     custom
#
#    class_type  object_resize  num_img_per_trial  num_trials_per_image  layers  \
# 3        seen          False                  4                     5     NaN
# 4        seen          False                  4                     5     NaN
# 5        seen          False                  4                     5     NaN
# 18       seen          False                  4                     5     NaN
# 19       seen          False                  4                     5     NaN
# 20       seen          False                  4                     5     NaN
# 33     unseen          False                  4                     5     NaN
# 34     unseen          False                  4                     5     NaN
# 35     unseen          False                  4                     5     NaN
# 48       full          False                  4                     5     NaN
# 49       full          False                  4                     5     NaN
# 50       full          False                  4                     5     NaN
#
#     top_k  map_file                              csv_save_path  \
# 3       1       NaN  ./experiments/trials/results/baseline.csv
# 4       1       NaN  ./experiments/trials/results/baseline.csv
# 5       1       NaN  ./experiments/trials/results/baseline.csv
# 18      1       NaN  ./experiments/trials/results/baseline.csv
# 19      1       NaN  ./experiments/trials/results/baseline.csv
# 20      1       NaN  ./experiments/trials/results/baseline.csv
# 33      1       NaN  ./experiments/trials/results/baseline.csv
# 34      1       NaN  ./experiments/trials/results/baseline.csv
# 35      1       NaN  ./experiments/trials/results/baseline.csv
# 48      1       NaN  ./experiments/trials/results/baseline.csv
# 49      1       NaN  ./experiments/trials/results/baseline.csv
# 50      1       NaN  ./experiments/trials/results/baseline.csv
#
#                      exps_root_dir                            trial_path  \
# 3   ./experiments/trials/baseline/    data/trials/seen_object_5_4_0.json
# 4   ./experiments/trials/baseline/    data/trials/seen_object_5_4_1.json
# 5   ./experiments/trials/baseline/    data/trials/seen_object_5_4_2.json
# 18  ./experiments/trials/baseline/    data/trials/seen_object_5_4_0.json
# 19  ./experiments/trials/baseline/    data/trials/seen_object_5_4_1.json
# 20  ./experiments/trials/baseline/    data/trials/seen_object_5_4_2.json
# 33  ./experiments/trials/baseline/  data/trials/unseen_object_5_4_0.json
# 34  ./experiments/trials/baseline/  data/trials/unseen_object_5_4_1.json
# 35  ./experiments/trials/baseline/  data/trials/unseen_object_5_4_2.json
# 48  ./experiments/trials/baseline/    data/trials/full_object_5_4_0.json
# 49  ./experiments/trials/baseline/    data/trials/full_object_5_4_1.json
# 50  ./experiments/trials/baseline/    data/trials/full_object_5_4_2.json
#
#                                           results_dir
# 3   ./experiments/trials/baseline/cvcl-resnext_cus...
# 4   ./experiments/trials/baseline/cvcl-resnext_cus...
# 5   ./experiments/trials/baseline/cvcl-resnext_cus...
# 18  ./experiments/trials/baseline/clip-res_custom_...
# 19  ./experiments/trials/baseline/clip-res_custom_...
# 20  ./experiments/trials/baseline/clip-res_custom_...
# 33  ./experiments/trials/baseline/clip-res_custom_...
# 34  ./experiments/trials/baseline/clip-res_custom_...
# 35  ./experiments/trials/baseline/clip-res_custom_...
# 48  ./experiments/trials/baseline/clip-res_custom_...
# 49  ./experiments/trials/baseline/clip-res_custom_...
# 50  ./experiments/trials/baseline/clip-res_custom_...

# %%
# Function to format accuracy with standard deviation
def format_acc(group):
    mean = group['overall_accuracy'].mean() * 100
    std = group['overall_accuracy'].std() * 100
    return f"{mean:.2f}±{std:.2f}%"

def cal_class_acc(df):
    # Group by model and class_type, then aggregate
    result = df.groupby(['model', 'class_type']).apply(format_acc).unstack()

    # Rename columns for clarity
    result.columns.name = None
    result = result.rename(columns={'unseen': 'Out-of-vocab', 'seen': 'In-vocab', 'full': 'All'})

    # Reorder columns
    result = result[['In-vocab', 'Out-of-vocab', 'All']]

    # Reset index to make 'model' a column
    result = result.reset_index()

    # Rename the 'model' column
    result = result.rename(columns={'model': 'Model'})

    # Display the result
    return result

# %%
vanilla_results = cal_class_acc(vanilla_4way_df)
print(vanilla_results)
# Out:
#           Model     In-vocab Out-of-vocab          All
# 0      clip-res  98.74±0.04%  96.94±0.08%  97.44±0.08%
# 1  cvcl-resnext  36.60±0.59%          NaN          NaN

# %%
neuron_result = cal_class_acc(neuron_df)
print(neuron_result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 neuron_result = cal_class_acc(neuron_df)
#       2 print(neuron_result)
#
# Cell In[4], line 16, in cal_class_acc(df)
#      13 result = result.rename(columns={'unseen': 'Unseen', 'seen': 'Seen', 'full': 'Full'})
#      15 # Reorder columns
# ---> 16 result = result[['Unseen', 'Seen', 'Full']]
#      18 # Reset index to make 'model' a column
#      19 result = result.reset_index()
#
# File ~/.conda/envs/prob_cvcl/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.conda/envs/prob_cvcl/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/.conda/envs/prob_cvcl/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Unseen', 'Full'] not in index"
